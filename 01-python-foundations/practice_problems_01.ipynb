# %% [markdown]
# <a href="https://colab.research.google.com/github/mirzatairin/AI-Programmer-Study-Archive/blob/main/01-python-foundations/practice_problems_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A simple dictionary problem. We define a dictionary with some food items
# We find the item that costs the most.
# We add another item to the evening_meal dictionary
# We print the updated dictionary

evening_meal = {"Dumplings": 300, "Icecream": 200, "Bubbletea": 180, "Coffee": 100}

# Calculate the sum of prices
total_price = sum(evening_meal.values())

# Calculate the number of items
num_items = len(evening_meal)

# Calculate the average price
average_price = total_price / num_items

# Find the most expensive item
# The `max()` function in Python is used to find the largest item in an iterable (like a list or a dictionary).
# `key=evening_meal.get` tells `max()` to compare items based on their values, not their keys.
# `evening_meal.get` is a method that retrieves the value associated with a given key.
# So, it finds the key (food item name) whose corresponding value (price) is the largest.
most_expensive_item = max(evening_meal, key=evening_meal.get)
max_price = evening_meal[most_expensive_item]

print(f"Food Items and Prices: {evening_meal}")
print(f"Total Price: {total_price:.2f}")
print(f"Number of Items: {num_items}")
print(f"Average Price: {average_price:.2f}")
print(f"The most expensive item is '{most_expensive_item}' with a price of {max_price:.2f}")


# Part 4: Add a new model
# Add the model MobileNet with an accuracy of 0.89
new_item = 'fuchka'
new_price = 50

# Add the new model to the dictionary
evening_meal[new_item] = new_price

print(f"Updated Food Items and Prices: {evening_meal}")
# Out:
# Food Items and Prices: {'Dumplings': 300, 'Icecream': 200, 'Bubbletea': 180, 'Coffee': 100}
# Total Price: 780.00
# Number of Items: 4
# Average Price: 195.00
# The most expensive item is 'Dumplings' with a price of 300.00
# Updated Food Items and Prices: {'Dumplings': 300, 'Icecream': 200, 'Bubbletea': 180, 'Coffee': 100, 'fuchka': 50}

# %%
# Define the animals dictionary as provided in the quiz
animals = {'dogs': [20, 10, 15, 8, 32, 15], 'cats': [3,4,2,8,2,4], 'rabbits': [2, 3, 3], 'fish': [0.3, 0.5, 0.8, 0.3, 1]}

print(f"Animals dictionary: {animals}")

# Demonstrating the quiz answers in code:

# The data type of the keys in the dictionary:
# The keys are 'dogs', 'cats', 'rabbits', 'fish', which are all strings.
print(f"\nData type of keys: {type(list(animals.keys())[0]).__name__}")

# The data type of the values in the dictionary:
# The values are lists of numbers.
print(f"Data type of values: {type(list(animals.values())[0]).__name__}")

# The result of animals['dogs']:
print(f"\nResult of animals['dogs']: {animals['dogs']}")

# The result of animals['dogs'][3]:
print(f"Result of animals['dogs'][3]: {animals['dogs'][3]}")

# The result of animals[3]:
# This would cause a KeyError because '3' is not a key in the dictionary.
try:
    print(f"Result of animals[3]: {animals[3]}")
except KeyError as e:
    print(f"Result of animals[3]: Error (KeyError: {e})")

# The result of animals['fish']:
print(f"Result of animals['fish']: {animals['fish']}")
# Out:
# Animals dictionary: {'dogs': [20, 10, 15, 8, 32, 15], 'cats': [3, 4, 2, 8, 2, 4], 'rabbits': [2, 3, 3], 'fish': [0.3, 0.5, 0.8, 0.3, 1]}
#
# Data type of keys: str
# Data type of values: list
#
# Result of animals['dogs']: [20, 10, 15, 8, 32, 15]
# Result of animals['dogs'][3]: 8
# Result of animals[3]: Error (KeyError: 3)
# Result of animals['fish']: [0.3, 0.5, 0.8, 0.3, 1]

# %%
#Compound Data Structures
#We can include containers in other containers to create compound data structures. For example, this dictionary maps keys to values that are also dictionaries!

elements = {"hydrogen": {"number": 1,
                         "weight": 1.00794,
                         "symbol": "H"},
              "helium": {"number": 2,
                         "weight": 4.002602,
                         "symbol": "He"}}
#We can access elements in this nested dictionary like this.
helium = elements["helium"]  # get the helium dictionary
hydrogen_weight = elements["hydrogen"]["weight"]  # get hydrogen's weight

#You can also add a new key to the element dictionary.

oxygen = {"number":8,"weight":15.999,"symbol":"O"}  # create a new oxygen dictionary
elements["oxygen"] = oxygen  # assign 'oxygen' as a key to the elements dictionary
print('elements = ', elements)

# %%
models = {
    'ResNet': {'layers': 50, 'accuracy': 0.91, 'type': 'CNN'},
    'MobileNet': {'layers': 28, 'accuracy': 0.89, 'type': 'CNN'}
}

# TODO: Add an 'is_lightweight' entry to the ResNet and MobileNet dictionaries
# hint: MobileNet is a lightweight model, ResNet isn't
models['ResNet']['is_lightweight'] = False
models['MobileNet']['is_lightweight'] = True

### Notebook grading
explanation_str = '''Your code produced the wrong result. Looks like you did not add the 'is_lightweight' property properly for {}.'''
if not('is_lightweight' in models['ResNet'].keys()) or models['ResNet']['is_lightweight'] != False:
    print(explanation_str.format("'ResNet'"))
elif not('is_lightweight' in models['MobileNet'].keys()) or models['MobileNet']['is_lightweight'] != True:
    print(explanation_str.format("'MobileNet'"))
else:
    print("""Your code passes all of our tests, nice work!""")
# Out:
# Your code passes all of our tests, nice work!

# %%
model_accuracy_dict = {
    'ResNet': 0.91, 'MobileNet': 0.89, 'VGG': 0.88, 'Inception': 0.92,
    'AlexNet': 0.85, 'EfficientNet': 0.93, 'SqueezeNet': 0.87
}

print(model_accuracy_dict, '\n')

# find number of unique keys in the dictionary
num_models = len(model_accuracy_dict)
print(num_models)

# find whether 'SqueezeNet' is a key in the dictionary
contains_squeezenet = 'SqueezeNet' in model_accuracy_dict
print(contains_squeezenet)

# create and sort a list of the dictionary's keys
sorted_keys = sorted(model_accuracy_dict.keys())
print(sorted_keys)

# get the first element in the sorted list of keys
first_key = sorted_keys[0]
print(first_key)

# find the element with the highest value in the dictionary
highest_accuracy_model = max(model_accuracy_dict, key=model_accuracy_dict.get)
print(highest_accuracy_model)
# Out:
# {'ResNet': 0.91, 'MobileNet': 0.89, 'VGG': 0.88, 'Inception': 0.92, 'AlexNet': 0.85, 'EfficientNet': 0.93, 'SqueezeNet': 0.87}
#
# 7
# True
# ['AlexNet', 'EfficientNet', 'Inception', 'MobileNet', 'ResNet', 'SqueezeNet', 'VGG']
# AlexNet
# EfficientNet

# %%
correct_num_models = 7
correct_contains_squeezenet = True
correct_first_key = 'AlexNet'
correct_highest_accuracy_model = 'EfficientNet'

if num_models != correct_num_models:
    print(f"Not quite! The number of unique models should be {correct_num_models}.")
elif contains_squeezenet != correct_contains_squeezenet:
    print(f"Not quite! Check if 'SqueezeNet' is a key in the dictionary.")
elif first_key != correct_first_key:
    print(f"Not quite! The first key when sorted should be {correct_first_key}.")
elif highest_accuracy_model != correct_highest_accuracy_model:
    print(f"Not quite! The model with the highest accuracy should be {correct_highest_accuracy_model}.")
else:
    print("Nice job! You can see my solution in the next page.")
